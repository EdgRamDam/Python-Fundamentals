# %% [markdown]
# ## Actualización de datos de rentabilidad LATAM para análsis de promociones

# %%
#1. Validación con finanzas de que el proceso de cierre de rentabilidad haya finalizado para los paises de LATAM
#2. Validación con finanzas de existencia de reprocesos de meses anteriores para paises de LATAM
#3. Ejecución del notebook en Data Bricks para extraer datos del último mes
#4. Ejecución del notebook en Data Bricks para extraer datos de meses con reproceso
#5. Validación de topline de ventas e ingresos de meses extraidos comparando con reportes oficiales de cierre
#6. Transformación de datos en Data Bricks para agrupar y estructurar el layout requerido para el análsis de promociones
#7. Validar que el trend de rentabilidad agrupada mantenga variaciones de +-5%
#8. Generar archivos y depositarlos en Storage Account utilzado para análisis de promociones
#9. Comunicar a los equipos involucrados que los datos de rentabilidad están listos para ser utilizados
