# %%
import pandas as pd

# %%
data = pd.read_csv("/dbfs/FileStore/shared_uploads/edgar.ramirezd@kof.com.mx/athlete_events.csv")

# %%
#data.display()

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más veterano que ha recibido medalla para los NOC´s MEX, COL y ARG (oro, plata o bronce) 
data1 = data[data["NOC"].isin(["MEX","COL","ARG"]) & data["Medal"].notnull()]
data1[data1["Age"] == data1["Age"].max()].display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Sex</th><th>Age</th><th>Height</th><th>Weight</th><th>Team</th><th>NOC</th><th>Games</th><th>Year</th><th>Season</th><th>City</th><th>Sport</th><th>Event</th><th>Medal</th></tr></thead><tbody><tr><td>110254</td><td>Julio Christian Sieburger Hadler</td><td>M</td><td>56.0</td><td>null</td><td>null</td><td>Djinn</td><td>ARG</td><td>1948 Summer</td><td>1948</td><td>Summer</td><td>London</td><td>Sailing</td><td>Sailing Mixed 6 metres</td><td>Silver</td></tr></tbody></table></div>

# %%
#Crear un programa en Visual Studio que me permita saber cuál es el competidor más joven que ha recibido medalla de oro para los NOC´s USA y CAN
data2 = data[data["NOC"].isin(["USA","CAN"]) & data["Medal"].isin(["Gold"])]
data2[data2["Age"] == data2["Age"].min()].display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Encuentra al competidor más ganador de la historia en medallas totales, medallas de oro, medallas de plata y medallas de broce para los NOC´s USA, CHN y RUS. Crea un csv con toda su información.
data3 = data[data["NOC"].isin(["USA","CHN","RUS"]) & data["Medal"].notnull()]
data3Agg = pd.DataFrame(data3.groupby(["Name"]).size().reset_index(name = "medal_count"))
resultado = data3Agg[data3Agg["medal_count"] == data3Agg["medal_count"].max()]
resultado.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>medal_count</th></tr></thead><tbody><tr><td>Michael Fred Phelps, II</td><td>28</td></tr></tbody></table></div>

# %%
resultado = data[data["Name"] == resultado["Name"].max()]
resultado.display()
resultado.to_csv("/dbfs/FileStore/shared_uploads/edgar.ramirezd@kof.com.mx/resultadoActiviadad12.csv",header=True,index=True)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls("dbfs:/FileStore/shared_uploads/edgar.ramirezd@kof.com.mx/")
# Out:
# Out[47]: [FileInfo(path='dbfs:/FileStore/shared_uploads/edgar.ramirezd@kof.com.mx/athlete_events.csv', name='athlete_events.csv', size=41229571, modificationTime=1664301953000),
#  FileInfo(path='dbfs:/FileStore/shared_uploads/edgar.ramirezd@kof.com.mx/resultadoActiviadad12.csv', name='resultadoActiviadad12.csv', size=4983, modificationTime=1664408305000)]
