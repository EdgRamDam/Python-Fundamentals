# %% [markdown]
# ## Ejercicio

# %%
tupla = (1,2.2,"3",False,["Elemento","5"])

# %%
tupla
# Out:
# Out[71]: (1, 2.2, '3', False, ['Elemento', '5'])

# %%
lista = list(tupla)

# %%
lista
# Out:
# Out[73]: [1, 2.2, '3', False, ['Elemento', '5']]

# %%
diccionario = dict.fromkeys(range(1,6))

# %%
diccionario
# Out:
# Out[83]: {1: None, 2: None, 3: None, 4: None, 5: None}

# %%
diccionario[1] = lista[0]
diccionario[2] = lista[1]
diccionario[3] = lista[2]
diccionario[4] = lista[3]
diccionario[5] = lista[4]

# %%
diccionario
# Out:
# Out[85]: {1: 1, 2: 2.2, 3: '3', 4: False, 5: ['Elemento', '5']}
