# %%
#2 * miEdad = 24
miEdad = 24 / 2
miEdad
# Out:
# Out[8]: 12.0

# %%
x = 6

# y/3 - 15 = x
y = (x + 15) * 3
y
# Out:
# Out[9]: 63

# %%
print("x es mas grande?")
print(x>y)

print("y es mas grande?")
print(y>x)
# Out:
# x es mas grande?
# False
# y es mas grande?
# True
